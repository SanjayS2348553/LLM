# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjayS2348553/LLM/blob/main/2348553_SANJAY_S_LLM_LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-dotenv
# !pip install langchain
# !pip install langchain-groq
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 637.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.3/990.3 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.2/374.2 kB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.7 MB/s eta 0:00:00
# ...

# %%
from dotenv import load_dotenv
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_groq import ChatGroq
import os

# %%
load_dotenv()

# Retrieve the API key from the environment variable
api_key = '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'
# Print the API key to ensure it is loaded correctly (for debugging purposes, remove this in production)
print(api_key)
# Out:
# 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

# %%
model = ChatGroq(api_key = api_key ,model_name = 'llama3-8b-8192')

# %%
parser = StrOutputParser()
chain = model | parser
chain.invoke('What is demonetisation')
# Out:
# "Demonetization is the process of stripping a currency unit of its status as legal tender. This means that the government declares the currency to be no longer valid for transactions, and people are required to exchange it for a new currency or other forms of payment.\n\nDemonetization is usually done to address economic or financial issues, such as:\n\n1. Inflation: High inflation can erode the value of money, making it difficult to conduct transactions. Demonetization can help to reduce inflation by removing excess currency from circulation.\n2. Corruption: In some cases, large amounts of cash are used to facilitate corruption and illegal activities. Demonetization can help to reduce the use of cash for illegal activities.\n3. Economic instability: Demonetization can be used to stabilize the economy by reducing the amount of currency in circulation, which can help to reduce inflation and stimulate economic growth.\n4. Transition to digital payments: Demonetization can be used to en
# ...

# %% [markdown]
# Question Answering

# %%
template = (
    """
    you're question answering expert
answer : {answer}
"""
)

# %%
prompt = PromptTemplate.from_template(template=template)

# %%
chain =  prompt | model | parser

# %%
answer = """
What is demonetisation
"""

# %%
result = chain.invoke({'answer':answer})
print(result)
# Out:
# A great question!
#
# Demonetization is the act of stripping a currency unit of its status as legal tender. In other words, it's a government's decision to withdraw a particular currency from circulation, making it no longer valid or accepted as a medium of exchange.
#
# In the context of India, demonetization refers to the surprise move made by the government on November 8, 2016, to ban the use of ₹500 and ₹1,000 banknotes, which were the highest denominations of currency in circulation at that time. The move was aimed at curbing black money, counterfeit currency, and terrorist financing.
#
# As a result of demonetization, these high-denomination notes were no longer legal tender, and people were required to deposit them in their bank accounts or exchange them for new, lower-denomination notes. The move was implemented to:
#
# ...

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma-7b-it')
parser = StrOutputParser()
chain = model | parser
chain.invoke('What is demonetisation')
# Out:
# '**Demonetisation** is the process of removing or reducing the use of cash in an economy. This can be done through various measures, such as increasing the cost of cash transactions, promoting digital payments, or reducing the availability of cash in circulation.\n\n\n**Objectives of demonetisation:**\n\n* **Economic efficiency:** To reduce transaction costs and increase efficiency by promoting digital payments.\n* **Financial inclusion:** To expand access to financial services for underserved populations by encouraging digital payments.\n* **Taxation:** To enhance tax compliance by making it more difficult to launder cash.\n* **Fraud reduction:** To reduce the risk of fraud and counterfeiting by limiting the use of physical cash.\n\n\n**Methods of demonetisation:**\n\n* **Increased transaction costs:** Implementing fees for cash transactions.\n* **Digital payment promotion:** Encouraging and incentivizing the use of digital wallets and online banking.\n* **Cash withdrawal limits:** 
# ...

# %%
model = ChatGroq(api_key = api_key ,model_name = 'gemma2-9b-it')
parser = StrOutputParser()
chain = model | parser
chain.invoke('What is demonetisation')
# Out:
# "Demonetisation is the act of stripping a currency unit of its status as legal tender. It involves withdrawing certain denominations of banknotes from circulation, typically older notes, and replacing them with new ones. \n\nHere's a breakdown of key aspects:\n\n**Purpose:**\n\nDemonetisation is often implemented for various reasons, including:\n\n* **Curbing black money:**  By suddenly invalidating old notes, it aims to discourage the holding of undeclared wealth and transactions.\n* **Combating counterfeiting:** Replacing old notes with redesigned, more secure ones can reduce the circulation of fake currency.\n* **Boosting financial inclusion:**  New notes may be designed with features encouraging people to use formal banking channels.\n* **Modernizing the currency system:** It can be a way to transition to a digital economy by encouraging people to adopt digital payment methods.\n\n**Impact:**\n\nDemonetisation can have both positive and negative consequences:\n\n**Potential Posit
# ...

# %% [markdown]
# From Gemini
# ![Screenshot 2024-07-16 130820.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# From Chat gpt
#
# ![Screenshot 2024-07-16 131217.jpg](data:image/jpeg;base64,...)
